# %% [markdown]
# # Pandas

# %% [markdown]
# ### Create New columns and Then Manipulate it

# %%
import pandas as pd

# %%
dataSales = pd.read_json("sample_Data.json")
dataSales.head()
# Out:
#    id                                         name  \
# 0   1                              Apple iPhone 12
# 1   2                           Samsung Galaxy S21
# 2   3                           Sony PlayStation 5
# 3   4            LG OLED55CXPUA 55-inch 4K OLED TV
# 4   5  Bose QuietComfort 35 II Wireless Headphones
#
#                                          description    price     category  \
# 0  The Apple iPhone 12 features a 6.1-inch Super ...   999.00  Electronics
# 1  The Samsung Galaxy S21 features a 6.2-inch Dyn...   799.00  Electronics
# 2  The Sony PlayStation 5 features an AMD Zen 2-b...   499.99  Electronics
# 3  The LG OLED55CXPUA 55-inch 4K OLED TV features...  1599.99  Electronics
# 4  The Bose QuietComfort 35 II Wireless Headphone...   299.00  Electronics
#
#                                                image
# 0  https://www.apple.com/newsroom/images/product/...
# 1  https://images.samsung.com/is/image/samsung/p6...
# ...

# %%
airData = pd.read_csv("air_quality_no2.csv")
airData.head()
# Out:
#               datetime  station_antwerp  station_paris  station_london
# 0  2019-05-07 02:00:00              NaN            NaN            23.0
# 1  2019-05-07 03:00:00             50.5           25.0            19.0
# 2  2019-05-07 04:00:00             45.0           27.7            19.0
# 3  2019-05-07 05:00:00              NaN           50.4            16.0
# 4  2019-05-07 06:00:00              NaN           61.9             NaN

# %%
airData["paris_mg_per_cubic"] = airData["station_paris"]*1.882
airData.head()
# Out:
#               datetime  station_antwerp  station_paris  station_london  \
# 0  2019-05-07 02:00:00              NaN            NaN            23.0
# 1  2019-05-07 03:00:00             50.5           25.0            19.0
# 2  2019-05-07 04:00:00             45.0           27.7            19.0
# 3  2019-05-07 05:00:00              NaN           50.4            16.0
# 4  2019-05-07 06:00:00              NaN           61.9             NaN
#
#    paris_mg_per_cubic
# 0                 NaN
# 1             47.0500
# 2             52.1314
# 3             94.8528
# 4            116.4958

# %%
dataSales["discounted"] = dataSales["price"]-0.1*dataSales["price"]
dataSales.head()
# Out:
#    id                                         name  \
# 0   1                              Apple iPhone 12
# 1   2                           Samsung Galaxy S21
# 2   3                           Sony PlayStation 5
# 3   4            LG OLED55CXPUA 55-inch 4K OLED TV
# 4   5  Bose QuietComfort 35 II Wireless Headphones
#
#                                          description    price     category  \
# 0  The Apple iPhone 12 features a 6.1-inch Super ...   999.00  Electronics
# 1  The Samsung Galaxy S21 features a 6.2-inch Dyn...   799.00  Electronics
# 2  The Sony PlayStation 5 features an AMD Zen 2-b...   499.99  Electronics
# 3  The LG OLED55CXPUA 55-inch 4K OLED TV features...  1599.99  Electronics
# 4  The Bose QuietComfort 35 II Wireless Headphone...   299.00  Electronics
#
#                                                image  discounted
# 0  https://www.apple.com/newsroom/images/product/...     899.100
# 1  https://images.samsung.com/is/image/samsung/p6...     719.100
# ...

# %%
dataSalesRe=dataSales.rename(
    columns={
    "discounted":"with discount"
}
)
dataSalesRe.head()
# Out:
#    id                                         name  \
# 0   1                              Apple iPhone 12
# 1   2                           Samsung Galaxy S21
# 2   3                           Sony PlayStation 5
# 3   4            LG OLED55CXPUA 55-inch 4K OLED TV
# 4   5  Bose QuietComfort 35 II Wireless Headphones
#
#                                          description    price     category  \
# 0  The Apple iPhone 12 features a 6.1-inch Super ...   999.00  Electronics
# 1  The Samsung Galaxy S21 features a 6.2-inch Dyn...   799.00  Electronics
# 2  The Sony PlayStation 5 features an AMD Zen 2-b...   499.99  Electronics
# 3  The LG OLED55CXPUA 55-inch 4K OLED TV features...  1599.99  Electronics
# 4  The Bose QuietComfort 35 II Wireless Headphone...   299.00  Electronics
#
#                                                image  with discount
# 0  https://www.apple.com/newsroom/images/product/...        899.100
# 1  https://images.samsung.com/is/image/samsung/p6...        719.100
# ...
